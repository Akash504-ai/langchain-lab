# %%
import os
from langchain_groq import ChatGroq
# from langchain.messages import HumanMessage

llm = ChatGroq(
    model="openai/gpt-oss-120b",
    api_key=os.environ.get("GROQ_API_KEY"),
    max_tokens=300
)

respondse = llm.invoke("Explain me python.")
# llm.invoke([
#     {"":""},
#     {"":""},
# ])
print(respondse.content)
# Out:
# ## Python – A Gentle Introduction
#
# Python is a high‑level, interpreted programming language that emphasizes readability and simplicity. It was created by **Guido van Rossum** in 1991 and has since become one of the most popular languages for everything from web development to data science, automation, scientific computing, and education.
#
# Below is a **road‑map‑style overview** that walks you through the most important concepts, with short code snippets you can try in a Python REPL (interactive shell) or a file.
#
# ---
#
# ## 1. Getting Started
#
# | What you need | How to get it |
# |---------------|---------------|
# | **Python interpreter** | Download from <https://python.org> (choose the latest stable version, e.g., 3.12). On macOS/Linux you often already have `python3` installed. |
# | **IDE / editor** | VS Code, PyCharm, Sublime Text, or even the built‑in IDLE. |
# | **
